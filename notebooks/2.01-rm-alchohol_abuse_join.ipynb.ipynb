# %% [markdown]
# Alchohol Abuse and Haunted Dataset Join
#
#
# Description:
#
# This notebook joins the alchohol abuse dataset with the cleaned haunted places dataset.
# It adds 2 features ("Total Deaths" and "% Under 21") to the haunted places dataset based on the "state" column using an inner join.

# %%
import pandas as pd

## Copy this code into your preamble. 

# Output Df
outfile = "../data/processed/haunted_places_features_added.tab"

# Reading CSV
haunted_places_df = pd.read_csv("../data/processed/haunted_places_cleaned.tab", sep = "\t")

# Feature Names
feature_names = ["Total Deaths", "% Under 21"]


# Get the 2 datasets (alchohol abuse and haunted places) 
alcohol_abuse_path = "../data/joined_datasets/alchohol_abuse_dataset.csv"
#haunted_places_path = "../data/processed/haunted_places_cleaned.tab"

# Load datasets
alcohol_abuse_df = pd.read_csv(alcohol_abuse_path)
#haunted_places_df = pd.read_csv(haunted_places_path, sep="\t")  # Tab-separated file

# Standardize column names for merging
alcohol_abuse_df.rename(columns={"State": "state"}, inplace=True)

# Merge datasets on 'state' column
merged_df = pd.merge(haunted_places_df, alcohol_abuse_df, on="state", how="inner")

# Save dataset
#merged_df.to_csv("../data/processed/merged_haunted_alcohol.csv", index=False)

## Save CSV ##
print("Saving to CSV...")

# Read Feature added dataframe
out_df = pd.read_csv(f"{outfile}", sep = "\t")


# Check if feature exists
for feature in feature_names:
    # Check if the feature exists in out_df columns
    if feature in out_df.columns:
        # Update values from merged_df (not haunted_places_df)
        out_df[feature].update(merged_df[feature].values)
    else:
        # If the feature doesn't exist, add it from merged_df
        out_df[feature] = merged_df[feature]


out_df.to_csv(f"{outfile}", sep = "\t", index = False)

print(f"CSV Saved to {outfile}")

# Display the merged dataframe 
print(merged_df)
# Out:
# Saving to CSV...
# /var/folders/5g/tck6nqw95lb8mx6m2ls7wj9r0000gq/T/ipykernel_23465/2433768332.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   out_df[feature].update(merged_df[feature].values)
# CSV Saved to ../data/processed/haunted_places_features_added.tab
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10970    Westminster  United States
# 10971    Westminster  United States
# 10972    Wheat Ridge  United States
# 10973    Wheat Ridge  United States
# 10974  Woodland Park  United States
#
#                                              description  \
# 0      ada witch sometimes see misty blue figure floa...
# 1      little girl killed suddenly waiting school bus...
# 2      take gorman rd . west towards sand creek come ...
# 3      1970 's one room room 211 old section dorms ex...
# 4      kappa delta sorority kappa delta sorority haun...
# ...                                                  ...
# 10970  12 midnight see lady two little girls looking ...
# 10971  haunted victims murder happened years ago haun...
# 10972  institution kids 18 years old younger . closed...
# 10973  gymnasium reports little girl girls locker roo...
# 10974  cadets air force academy participating surviva...
#
#                         location     state state_abbrev   longitude  \
# 0                   Ada Cemetery  Michigan           MI  -85.504893
# 1                North Adams Rd.  Michigan           MI  -84.381843
# 2                  Ghost Trestle  Michigan           MI  -84.035656
# 3       Siena Heights University  Michigan           MI  -84.017565
# 4                 Albion College  Michigan           MI  -84.745177
# ...                          ...       ...          ...         ...
# 10970                  city hall  Colorado           CO -105.048936
# 10971             Pillar of Fire  Colorado           CO -105.032091
# 10972   Ridge Mental Institution  Colorado           CO -105.063974
# 10973  Wheat Ridge Middle School  Colorado           CO -105.103613
# 10974         Saylor Park Forest  Colorado           CO -105.022763
#
#         latitude  city_longitude  city_latitude Total Deaths % Under 21
# 0      42.962106      -85.495480      42.960727        4,548      2.60%
# 1      41.971425      -84.347168      41.986434        4,548      2.60%
# 2      41.904538      -84.037166      41.897547        4,548      2.60%
# 3      41.905712      -84.037166      41.897547        4,548      2.60%
# 4      42.244006      -84.753030      42.243097        4,548      2.60%
# ...          ...             ...            ...          ...        ...
# 10970  39.862610     -105.037205      39.836653        2,623      2.80%
# 10971  39.847237     -105.037205      39.836653        2,623      2.80%
# 10972  39.769726     -105.077206      39.766098        2,623      2.80%
# 10973  39.764055     -105.077206      39.766098        2,623      2.80%
# 10974  39.116658     -105.056930      38.993881        2,623      2.80%
#
# [10975 rows x 12 columns]
